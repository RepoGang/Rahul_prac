# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
URL = 'https://dir.indiamart.com/impcat/car-parts.html'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup2.find_all('h3')
title2 = soup2.find_all('h2')

#price = soup2.find(id='priceblock_ourprice').get_text()


print(title)
print(title2)
#print(price)
# Out:
# [<h3>
#                    Thermostate Elbow Tata Tiago
#                   </h3>, <h3>
#                    Indian Iron Universal Bumper Clip, For Automotive
#                   </h3>, <h3>
#                    DIFFERS 4 Wheelers Tata Car Spare Parts, For Automotive
#                   </h3>, <h3>
#                    VW AUDI Q7 4L0 2006-2014 SRS AIRBAG CONTROL MODULE 4L0959655C 4L0959655D
#                   </h3>, <h3 class="lg eq" data-click="^Prod0Name">
#                   Head elbow for Volkswagen vento diesel quality product durable made in Malaysia
#                  </h3>, <h3>
#                    ABS + Glass Car Mercedes-Benz C class w204 hid, For Automotive
#                   </h3>, <h3>
#                    Elbow Swift New
#                   </h3>, <h3>
#                    Plastic Audi Q7 Bumper Reflectors, For Automotive
#                   </h3>, <h3>
#                    Iron Upper Control Arm For Porsche Panamera
#                   </h3>, <h3>
#                    hanon blower motor xuv
#                   </h3>, <h3>
#                    Stainless Steel Car Dicky Shocker, For Domestic, 20*2*2
#                   </h3>, <h3>
#                    Black Plastic Volkswagen BCM Vento
#                   </h3>, <h3>
#                    Rubber Audi Car Suspension Balloon, For Industrial
#                   </h3>, <h3 class="lg eq" data-click="^Prod0Name">
#                   Turbo Pipe Lock Skoda, Audi, VW
#                  </h3>, <h3>
#                    German Continental Airmatic Valve Block Mercedes-Benz, For Automobile Industry
#                   </h3>, <h3>
#                    Regulador De Ventana Lateral Izquierdo Y Derecho Para Suzuki Samurai Sj410 Sj413 Sierra
#                   </h3>, <h3>
#                    AMP Hard Cast Aluminium Brush Holder for Cars, For Automotive
#                   </h3>, <h3>
#                    RUBBER Car Parts, For Automotive, Vehicle Model: Bmw 5 Series
#                   </h3>, <h3>
#                    Renault Duster Trunk Lid
#                   </h3>, <h3>
#                    Imported BENZ GLS, Model Name/Number: W166
#                   </h3>, <h3 class="lg eq" data-click="^Prod0Name">
#                   ALL LUXURY CARS SPARES PARTS
#                  </h3>, <h3>
#                    Hard Cast Aluminium Automatic Gear Chain
#                   </h3>, <h3>
#                    Pc And Abs, Rubberized Coating Atoz e Class Ac Vent For Mercedes Benz W212 2128301354, For Automotive
#                   </h3>, <h3>
#                    Dullabh EN8 Automotive Car Spare Parts, For Industrial
#                   </h3>, <h3>
#                    Bolero Maxi Plus Urea Doser
#                   </h3>, <h3>
#                    Volvo 210 B Prime Voe 20886142 Wiring Harness
#                   </h3>, <h3>
#                    Door Rubber for Cars
#                   </h3>, <h3>
#                    Plastic BMW 5 Series F10 Parking Switch Cover, For Automotive
#                   </h3>]
# [<h2 class="lcname" data-click="^CompanyName">
#                 New Asian Motors
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 M/S Automobile Villa
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 M/s.OM D.P. MARKETING
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Zam Zam Enterprise
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Lokesh Enterprises
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Luxury Spares
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Accumate Brakes India
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 ADS Auto
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Mahudi Impex
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Autoair India
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Pranay International
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 BBN International
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Unique Auto Spares
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 JAIN &amp; CO
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Ilife Retail Private Limited
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 SAI OVERSEAS
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Amp Impex Private Limited
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Vardhaman Auto Parts
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Assurer
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Bhavika Enterprises
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Unique Motor
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Lucky Traders
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 A TO Z SUSPENSION PARTS
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Dullabh Commercials
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Turbo Tech Engineers
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 SR Earth Movers
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Kamal Automobiles
#                </h2>, <h2 class="lcname" data-click="^CompanyName">
#                 Calcutta Motors
#                </h2>]

# %%
import pandas as pd 
df = pd.DataFrame(list(zip(title, title2)),
               columns =['product name', 'company name'])
print(df)
df.head()
# Out:
#                                          product name  \
# 0   [\n                   Thermostate Elbow Tata T...
# 1   [\n                   Indian Iron Universal Bu...
# 2   [\n                   DIFFERS 4 Wheelers Tata ...
# 3   [\n                   VW AUDI Q7 4L0 2006-2014...
# 4   [\n                  Head elbow for Volkswagen...
# 5   [\n                   ABS + Glass Car Mercedes...
# 6   [\n                   Elbow Swift New\n       ...
# 7   [\n                   Plastic Audi Q7 Bumper R...
# 8   [\n                   Iron Upper Control Arm F...
# 9   [\n                   hanon blower motor xuv\n...
# 10  [\n                   Stainless Steel Car Dick...
# 11  [\n                   Black Plastic Volkswagen...
# 12  [\n                   Rubber Audi Car Suspensi...
# 13  [\n                  Turbo Pipe Lock Skoda, Au...
# 14  [\n                   German Continental Airma...
# 15  [\n                   Regulador De Ventana Lat...
# 16  [\n                   AMP Hard Cast Aluminium ...
# 17  [\n                   RUBBER Car Parts, For Au...
# 18  [\n                   Renault Duster Trunk Lid...
# 19  [\n                   Imported BENZ GLS, Model...
# 20  [\n                  ALL LUXURY CARS SPARES PA...
# 21  [\n                   Hard Cast Aluminium Auto...
# 22  [\n                   Pc And Abs, Rubberized C...
# 23  [\n                   Dullabh EN8 Automotive C...
# 24  [\n                   Bolero Maxi Plus Urea Do...
# 25  [\n                   Volvo 210 B Prime Voe 20...
# 26  [\n                   Door Rubber for Cars\n  ...
# 27  [\n                   Plastic BMW 5 Series F10...
#
#                                          company name
# 0   [\n                New Asian Motors\n         ...
# 1   [\n                M/S Automobile Villa\n     ...
# 2   [\n                M/s.OM D.P. MARKETING\n    ...
# 3   [\n                Zam Zam Enterprise\n       ...
# 4   [\n                Lokesh Enterprises\n       ...
# 5   [\n                Luxury Spares\n            ...
# 6   [\n                Accumate Brakes India\n    ...
# 7       [\n                ADS Auto\n               ]
# 8   [\n                Mahudi Impex\n               ]
# 9   [\n                Autoair India\n            ...
# 10  [\n                Pranay International\n     ...
# 11  [\n                BBN International\n        ...
# 12  [\n                Unique Auto Spares\n       ...
# 13     [\n                JAIN & CO\n               ]
# 14  [\n                Ilife Retail Private Limite...
# 15  [\n                SAI OVERSEAS\n               ]
# 16  [\n                Amp Impex Private Limited\n...
# 17  [\n                Vardhaman Auto Parts\n     ...
# 18       [\n                Assurer\n               ]
# 19  [\n                Bhavika Enterprises\n      ...
# 20  [\n                Unique Motor\n               ]
# 21  [\n                Lucky Traders\n            ...
# 22  [\n                A TO Z SUSPENSION PARTS\n  ...
# 23  [\n                Dullabh Commercials\n      ...
# 24  [\n                Turbo Tech Engineers\n     ...
# 25  [\n                SR Earth Movers\n          ...
# 26  [\n                Kamal Automobiles\n        ...
# 27  [\n                Calcutta Motors\n          ...
#                                         product name  \
# 0  [\n                   Thermostate Elbow Tata T...
# 1  [\n                   Indian Iron Universal Bu...
# 2  [\n                   DIFFERS 4 Wheelers Tata ...
# 3  [\n                   VW AUDI Q7 4L0 2006-2014...
# 4  [\n                  Head elbow for Volkswagen...
#
#                                         company name
# 0  [\n                New Asian Motors\n         ...
# 1  [\n                M/S Automobile Villa\n     ...
# 2  [\n                M/s.OM D.P. MARKETING\n    ...
# 3  [\n                Zam Zam Enterprise\n       ...
# 4  [\n                Lokesh Enterprises\n       ...

# %%
# Out:
#                                          product name  \
# 0   [\n                   Thermostate Elbow Tata T...
# 1   [\n                   Indian Iron Universal Bu...
# 2   [\n                   DIFFERS 4 Wheelers Tata ...
# 3   [\n                   VW AUDI Q7 4L0 2006-2014...
# 4   [\n                  Head elbow for Volkswagen...
# 5   [\n                   ABS + Glass Car Mercedes...
# 6   [\n                   Elbow Swift New\n       ...
# 7   [\n                   Plastic Audi Q7 Bumper R...
# 8   [\n                   Iron Upper Control Arm F...
# 9   [\n                   hanon blower motor xuv\n...
# 10  [\n                   Stainless Steel Car Dick...
# 11  [\n                   Black Plastic Volkswagen...
# 12  [\n                   Rubber Audi Car Suspensi...
# 13  [\n                  Turbo Pipe Lock Skoda, Au...
# 14  [\n                   German Continental Airma...
# 15  [\n                   Regulador De Ventana Lat...
# 16  [\n                   AMP Hard Cast Aluminium ...
# 17  [\n                   RUBBER Car Parts, For Au...
# 18  [\n                   Renault Duster Trunk Lid...
# 19  [\n                   Imported BENZ GLS, Model...
# 20  [\n                  ALL LUXURY CARS SPARES PA...
# 21  [\n                   Hard Cast Aluminium Auto...
# 22  [\n                   Pc And Abs, Rubberized C...
# 23  [\n                   Dullabh EN8 Automotive C...
# 24  [\n                   Bolero Maxi Plus Urea Do...
# 25  [\n                   Volvo 210 B Prime Voe 20...
# 26  [\n                   Door Rubber for Cars\n  ...
# 27  [\n                   Plastic BMW 5 Series F10...
#
#                                          company name
# 0   [\n                New Asian Motors\n         ...
# 1   [\n                M/S Automobile Villa\n     ...
# 2   [\n                M/s.OM D.P. MARKETING\n    ...
# 3   [\n                Zam Zam Enterprise\n       ...
# 4   [\n                Lokesh Enterprises\n       ...
# 5   [\n                Luxury Spares\n            ...
# 6   [\n                Accumate Brakes India\n    ...
# 7       [\n                ADS Auto\n               ]
# 8   [\n                Mahudi Impex\n               ]
# 9   [\n                Autoair India\n            ...
# 10  [\n                Pranay International\n     ...
# 11  [\n                BBN International\n        ...
# 12  [\n                Unique Auto Spares\n       ...
# 13     [\n                JAIN & CO\n               ]
# 14  [\n                Ilife Retail Private Limite...
# 15  [\n                SAI OVERSEAS\n               ]
# 16  [\n                Amp Impex Private Limited\n...
# 17  [\n                Vardhaman Auto Parts\n     ...
# 18       [\n                Assurer\n               ]
# 19  [\n                Bhavika Enterprises\n      ...
# 20  [\n                Unique Motor\n               ]
# 21  [\n                Lucky Traders\n            ...
# 22  [\n                A TO Z SUSPENSION PARTS\n  ...
# 23  [\n                Dullabh Commercials\n      ...
# 24  [\n                Turbo Tech Engineers\n     ...
# 25  [\n                SR Earth Movers\n          ...
# 26  [\n                Kamal Automobiles\n        ...
# 27  [\n                Calcutta Motors\n          ...
#                                         product name  \
# 0  [\n                   Thermostate Elbow Tata T...
# 1  [\n                   Indian Iron Universal Bu...
# 2  [\n                   DIFFERS 4 Wheelers Tata ...
# 3  [\n                   VW AUDI Q7 4L0 2006-2014...
# 4  [\n                  Head elbow for Volkswagen...
#
#                                         company name
# 0  [\n                New Asian Motors\n         ...
# 1  [\n                M/S Automobile Villa\n     ...
# 2  [\n                M/s.OM D.P. MARKETING\n    ...
# 3  [\n                Zam Zam Enterprise\n       ...
# 4  [\n                Lokesh Enterprises\n       ...
